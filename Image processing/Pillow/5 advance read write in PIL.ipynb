# %%
from PIL import Image
from __future__ import print_function

# %%
img=Image.open('Images/joy.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=196x182 at 0x2C8D50CB2B0>

# %% [markdown]
# ## Reading from an open file

# %%
file=open('Images/joy.png',"rb")
image=Image.open(file)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=196x182 at 0x2C8D49225E0>

# %% [markdown]
# ## Reading from a tar archive

# %%
'''
from PIL import TarIO
fp=TarIO.TarIO('Imaging.tar','Imaging/test/lena.ppm')
image=Image.open(fb)
'''
# Out:
# "\nfrom PIL import TarIO\nfp=TarIO.TarIO('Imaging.tar','Imaging/test/lena.ppm')\nimage=Image.open(fb)\n"

# %% [markdown]
# ## Reading in draf mode

# %%
from __future__ import print_function
image=Image.open(file)
print("Original : ",image.mode, image.size)

image.draft('L',(100,100))
print("Draft: ",image.mode, image.size)
# Out:
# Original :  RGBA (196, 182)
# Draft:  RGBA (196, 182)
