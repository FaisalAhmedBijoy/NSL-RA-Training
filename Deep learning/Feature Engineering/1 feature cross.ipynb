# %% [markdown]
# ## Plot random data point

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# df = pd.read_csv('geoloc_elev.csv')
df = pd.read_csv('https://raw.githubusercontent.com/raqueeb/TensorFlow2/master/datasets/geoloc_elev.csv')

# আমাদের দুটো ফিচার হলেই যথেষ্ট 
X = df[['lat', 'lon']].values
y = df['target'].values

# %%
X.shape , y.shape
# Out:
# ((1500, 2), (1500,))

# %%
df.plot(kind='scatter',
        x='lat',
        y='lon',
        c='target',
        cmap='bwr');

# %% [markdown]
# There is two area and we have to distinguish this two area.
# - Support Vector Machine
# - Neural Network

# %%
from sklearn.svm import SVC
clf=SVC(gamma='auto')
clf.fit(X,y)
# Out:
# SVC(gamma='auto')

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X=X,y=y,clf=clf,legend=2)
plt.xlabel('x',size=5)
plt.ylabel('y',size=5)
plt.title('SVM Decision Region Boundary',size=6)
plt.show()

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test=train_test_split(X,y,test_size=0.3)

# %% [markdown]
# ## Use Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.66

# %% [markdown]
# ## Classification using Neural network

# %%
import tensorflow as tf

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Dense(1,input_dim=2,activation='tanh'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(tf.keras.optimizers.SGD(lr=0.5),'binary_crossentropy',metrics=['accuracy'])
result=model.fit(x_train,y_train,epochs=20,validation_split=0.1)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 0s 16ms/step - loss: 0.6483 - accuracy: 0.6296 - val_loss: 0.6046 - val_accuracy: 0.7048
# Epoch 2/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6298 - accuracy: 0.6656 - val_loss: 0.5875 - val_accuracy: 0.7048
# Epoch 3/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6131 - accuracy: 0.6656 - val_loss: 0.5728 - val_accuracy: 0.7048
# Epoch 4/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5959 - accuracy: 0.6656 - val_loss: 0.5461 - val_accuracy: 0.7048
# Epoch 5/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.6656 - val_loss: 0.5285 - val_accuracy: 0.7048
# Epoch 6/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5639 - accuracy: 0.6519 - val_loss: 0.5203 - val_accuracy: 0.7048
# Epoch 7/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5589 - accuracy: 0.6360 - val_loss: 0.5166 - val_accuracy: 0.4476
# Epoch 8/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5533 - accuracy: 0.6455 - val_loss: 0.5030 - val_accuracy: 0.7048
# Epoch 9/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5475 - accuracy: 0.6402 - val_loss: 0.4973 - val_accuracy: 0.7048
# Epoch 10/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5425 - accuracy: 0.6656 - val_loss: 0.4934 - val_accuracy: 0.7048
# Epoch 11/20
# 30/30 [==============================] - ETA: 0s - loss: 0.4747 - accuracy: 0.81 - 0s 1ms/step - loss: 0.5408 - accuracy: 0.6370 - val_loss: 0.4913 - val_accuracy: 0.7048
# Epoch 12/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5376 - accuracy: 0.6656 - val_loss: 0.4929 - val_accuracy: 0.7048
# Epoch 13/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5349 - accuracy: 0.6487 - val_loss: 0.4873 - val_accuracy: 0.7048
# Epoch 14/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5327 - accuracy: 0.6656 - val_loss: 0.4860 - val_accuracy: 0.7048
# Epoch 15/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5314 - accuracy: 0.6540 - val_loss: 0.4852 - val_accuracy: 0.7048
# Epoch 16/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5327 - accuracy: 0.6444 - val_loss: 0.4840 - val_accuracy: 0.7048
# Epoch 17/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5297 - accuracy: 0.6561 - val_loss: 0.4833 - val_accuracy: 0.7048
# Epoch 18/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5279 - accuracy: 0.6656 - val_loss: 0.4827 - val_accuracy: 0.7048
# Epoch 19/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5238 - accuracy: 0.6317 - val_loss: 0.4863 - val_accuracy: 0.7048
# Epoch 20/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5269 - accuracy: 0.6656 - val_loss: 0.4838 - val_accuracy: 0.7048

# %%
pd.DataFrame(result.history)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.648329  0.629630  0.604614      0.704762
# 1   0.629847  0.665608  0.587550      0.704762
# 2   0.613143  0.665608  0.572836      0.704762
# 3   0.595859  0.665608  0.546145      0.704762
# 4   0.579728  0.665608  0.528483      0.704762
# 5   0.563937  0.651852  0.520317      0.704762
# 6   0.558891  0.635979  0.516585      0.447619
# 7   0.553327  0.645503  0.502953      0.704762
# 8   0.547525  0.640212  0.497314      0.704762
# 9   0.542493  0.665608  0.493364      0.704762
# 10  0.540771  0.637037  0.491334      0.704762
# 11  0.537616  0.665608  0.492871      0.704762
# 12  0.534894  0.648677  0.487262      0.704762
# 13  0.532728  0.665608  0.485968      0.704762
# 14  0.531439  0.653968  0.485150      0.704762
# 15  0.532719  0.644444  0.484037      0.704762
# 16  0.529665  0.656085  0.483313      0.704762
# 17  0.527891  0.665608  0.482738      0.704762
# 18  0.523823  0.631746  0.486332      0.704762
# 19  0.526859  0.665608  0.483840      0.704762

# %%
pd.DataFrame(result.history).plot(ylim=(-0.05,1.05))
# Out:
# <AxesSubplot:>

# %%
history=model.evaluate(x_test,y_test)
# Out:
#  1/15 [=>............................] - ETA: 0s - loss: 0.5415 - accuracy: 0.5625WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 15/15 [==============================] - 0s 731us/step - loss: 0.5280 - accuracy: 0.6600

# %%
print(history[1] * 100)
# Out:
# 66.00000262260437

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(4, input_dim=2, activation='tanh'),
    # এই লেয়ার পরে যোগ করে আমরা দেখবো 
    # tf.keras.layers.Dense(4, activation='tanh'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(tf.keras.optimizers.SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])
h = model.fit(x_train, y_train, epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6516 - accuracy: 0.6349 - val_loss: 0.6124 - val_accuracy: 0.7048
# Epoch 2/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6246 - accuracy: 0.6656 - val_loss: 0.5838 - val_accuracy: 0.7048
# Epoch 3/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5896 - accuracy: 0.6656 - val_loss: 0.5388 - val_accuracy: 0.7048
# Epoch 4/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5233 - accuracy: 0.7048 - val_loss: 0.4691 - val_accuracy: 0.7048
# Epoch 5/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4432 - accuracy: 0.8063 - val_loss: 0.4035 - val_accuracy: 0.8667
# Epoch 6/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3853 - accuracy: 0.8709 - val_loss: 0.3593 - val_accuracy: 0.8762
# Epoch 7/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3477 - accuracy: 0.8730 - val_loss: 0.3348 - val_accuracy: 0.8667
# Epoch 8/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3281 - accuracy: 0.8656 - val_loss: 0.3247 - val_accuracy: 0.8667
# Epoch 9/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3131 - accuracy: 0.8709 - val_loss: 0.3063 - val_accuracy: 0.8667
# Epoch 10/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3043 - accuracy: 0.8815 - val_loss: 0.3016 - val_accuracy: 0.8667
# Epoch 11/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3004 - accuracy: 0.8762 - val_loss: 0.2945 - val_accuracy: 0.8667
# Epoch 12/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2929 - accuracy: 0.8762 - val_loss: 0.3075 - val_accuracy: 0.8571
# Epoch 13/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2900 - accuracy: 0.8720 - val_loss: 0.3040 - val_accuracy: 0.8571
# Epoch 14/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2827 - accuracy: 0.8794 - val_loss: 0.2857 - val_accuracy: 0.8667
# Epoch 15/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2594 - accuracy: 0.8836 - val_loss: 0.2395 - val_accuracy: 0.8857
# Epoch 16/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1989 - accuracy: 0.9185 - val_loss: 0.1694 - val_accuracy: 0.9333
# Epoch 17/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.1352 - accuracy: 0.9831 - val_loss: 0.1189 - val_accuracy: 1.0000
# Epoch 18/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0961 - accuracy: 0.9968 - val_loss: 0.0852 - val_accuracy: 1.0000
# Epoch 19/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0743 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 1.0000
# Epoch 20/20
# 30/30 [==============================] - 0s 1ms/step - loss: 0.0607 - accuracy: 1.0000 - val_loss: 0.0554 - val_accuracy: 1.0000

# %%
pd.DataFrame(h.history).plot(ylim=(-0.05,1.05))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred=model.predict_classes(x_test)
# Out:
# WARNING:tensorflow:From <ipython-input-36-b7e8b0f72a66>:2: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
y_pred[:5]
# Out:
# array([[1],
#        [0],
#        [1],
#        [0],
#        [0]])

# %%
cm=confusion_matrix(y_test,y_pred)
pd.DataFrame(cm, index=['Miss','Hit'],columns=['pred_Miss','pred_Hit'])
# Out:
#       pred_Miss  pred_Hit
# Miss        296         1
# Hit           0       153

# %%
hticks = np.linspace(-2, 2, 101)
vticks = np.linspace(-2, 2, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]

c = model.predict(ab)
cc = c.reshape(aa.shape)

ax = df.plot(kind='scatter', c='target', x='lat', y='lon', cmap='bwr')
ax.contourf(aa, bb, cc, cmap='bwr', alpha=0.5)
