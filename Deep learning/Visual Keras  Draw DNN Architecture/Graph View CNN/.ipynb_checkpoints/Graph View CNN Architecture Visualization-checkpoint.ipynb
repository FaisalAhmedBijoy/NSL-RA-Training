# %% [markdown]
# ## Import Library

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %% [markdown]
# ## Create Conv Relu BatchNormalization Block

# %%
def conv_relu_batchnorm(x, filters, kernel_size):
    x = layers.Conv2D(filters=filters,
               kernel_size=kernel_size,
               activation='relu',
               padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    return x

# %% [markdown]
# ## Create Layers Concatenation Block

# %%
def layer_concate(tensor,filters):
    x=conv_relu_batchnorm(tensor,filters,kernel_size=3)
    x=layers.Concatenate()([x,tensor])
    return x

# %% [markdown]
# ## Define Model Input

# %%
inputs=layers.Input(shape=(224,224,3))

# %% [markdown]
# ## Define Model Architecture

# %%
total_class=6

# %%
x=conv_relu_batchnorm(inputs,filters=32,kernel_size=3)
x=layers.MaxPool2D(pool_size=(2,2))(x)
x=layer_concate(x,filters=64)
x=layers.MaxPool2D(pool_size=(3,3))(x)

# %%
x=conv_relu_batchnorm(x,filters=128,kernel_size=3)
x=layers.MaxPool2D(pool_size=(3,3))(x)
x=layer_concate(x,filters=256)
x=layers.MaxPool2D(pool_size=(3,3))(x)

# %%
x=layers.Dropout(0.2)(x)
x=layers.Flatten()(x)
x=layers.Dense(256,activation='relu')(x)

# %% [markdown]
# ## Define Output Layer

# %%
output=layers.Dense(total_class,activation='softmax')(x)

# %% [markdown]
# ## Create Hybrid CNN Model

# %%
model=keras.Model(inputs,output,name='HybridCNN')

# %%
model.summary()
# Out:
# Model: "HybridCNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 112, 112, 96) 0           batch_normalization_1[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 37, 37, 96)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 37, 37, 128)  110720      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 37, 37, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 12, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 12, 12, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 384)  0           batch_normalization_3[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 384)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4, 4, 384)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 6144)         0           dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          1573120     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 6)            1542        dense[0][0]
# ==================================================================================================
# Total params: 2,001,862
# Trainable params: 2,000,902
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %% [markdown]
# ## Plot Model

# %%
image_name='HybridGraphCNN.png'
keras.utils.plot_model(model,show_shapes=True,to_file=image_name)

# %% [markdown]
# ## Visualize with Visual Keras

# %%
import visualkeras

# %%
visualkeras.graph_view(model).show()
visualkeras.graph_view(model,to_file='Graph_Hybrid_cnn_architecture.png')
visualkeras.graph_view(model,to_file='Graph_Hybird_cnn_architecture.png').show()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Legend

# %%
from PIL import ImageFont
font=ImageFont.truetype('arial.ttf',32)
visualkeras.graph_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=5770x610 at 0x18A58874400>

# %% [markdown]
# ## Flat Style

# %%
visualkeras.graph_view(model,
                         to_file='Graph_hybrid_flat_cnn.png',
                     )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b8af43257b2d> in <module>
# ----> 1 visualkeras.graph_view(model,
#       2                          to_file='Graph_hybrid_flat_cnn.png',
#       3                          draw_volume=False)
#
# TypeError: graph_view() got an unexpected keyword argument 'draw_volume'

# %% [markdown]
# ## Spacing and logic grouping

# %%
#model.add(visualkeras.SpacingDummyLayer(spacing=100))
visualkeras.graph_view(model,layer_spacing=100,show_neurons=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=2920x610 at 0x18A552B0EB0>

# %%
visualkeras.graph_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=5770x610 at 0x18A5845BBE0>

# %%
visualkeras.layered_view(model,legend=True,spacing=100)
# Out:
# <PIL.Image.Image image mode=RGBA size=2805x1231 at 0x18A58371040>

# %% [markdown]
# ## Custom Color Map
# it is possible to provide a custom color map for fill and outline per layer type

# %%
from collections import defaultdict

# %%
dict=[]

# %%
color_map=defaultdict()

# %%
color_map['Conv2D']['fill']='orange'
color_map['MaxPooling2D']['fill']='gray'
color_map['Dense']['fill']='green'
color_map['Dropout']['fill']='pink'
color_map['Flatten']['fill']='teal'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-90efa389a3a3> in <module>
# ----> 1 color_map['Conv2D']['fill']='orange'
#       2 color_map['MaxPooling2D']['fill']='gray'
#       3 color_map['Dense']['fill']='green'
#       4 color_map['Dropout']['fill']='pink'
#       5 color_map['Flatten']['fill']='teal'
#
# KeyError: 'Conv2D'

# %%
visualkeras.layered_view(model,color_map=color_map,spacing=100,legend=True,font=font)
# Out:
# <PIL.Image.Image image mode=RGBA size=2041x1267 at 0x1DAD5A4C3D0>

# %% [markdown]
# ## Scaling Dimension

# %%
visualkeras.graph_view(model,
                         to_file='scaling_hyrbid_cnn.png',
                         scale_xy=1,
                         scale_z=1,
                         max_z=100,
                        spacing=10,
                         legend=True,
                         font=font
                        )
# Out:
# <PIL.Image.Image image mode=RGBA size=1697x433 at 0x20CBF180970>
