# %%
print('Data Augmentation using ImageDataGenerator')
# Out:
# Data Augmentation using ImageDataGenerator

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing import image

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img=image.load_img('mosque35.png')
plt.imshow(img)

# %%
datagen=image.ImageDataGenerator()
datagen

# %%
#convert numpy array
data=image.img_to_array(img)
# expand the dimension
samples=np.expand_dims(data,0)

# %% [markdown]
# ## Horizontal and vertical shift

# %%
shift_datagen=image.ImageDataGenerator(width_shift_range=[-100,100])
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <tensorflow.python.keras.preprocessing.image.NumpyArrayIterator object at 0x000001E51993E520>

# %%
shift_datagen=image.ImageDataGenerator(height_shift_range=0.5)
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <tensorflow.python.keras.preprocessing.image.NumpyArrayIterator object at 0x000001E5198CFA60>

# %% [markdown]
# ## Horizontal and vertical flip augmentation

# %%
flip_datagen=image.ImageDataGenerator(horizontal_flip=True)
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <tensorflow.python.keras.preprocessing.image.NumpyArrayIterator object at 0x000001E51B1A0280>

# %%
flip_datagen=image.ImageDataGenerator(vertical_flip=True)
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <tensorflow.python.keras.preprocessing.image.NumpyArrayIterator object at 0x000001E519B1DF70>

# %% [markdown]
# ## Random rotation augmentation

# %%
rotation_datagen=image.ImageDataGenerator(rotation_range=90)
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <tensorflow.python.keras.preprocessing.image.NumpyArrayIterator object at 0x000001E51B175B50>

# %% [markdown]
# ## Random brightness augmentation

# %%
brightness_datagen=image.ImageDataGenerator(brightness_range=[0.2,1.0])
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <tensorflow.python.keras.preprocessing.image.NumpyArrayIterator object at 0x000001E519BDBFD0>

# %% [markdown]
# ## Random zoom augmentation

# %%
zoom_datagen=image.ImageDataGenerator(zoom_range=[0.5,1.0])
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <tensorflow.python.keras.preprocessing.image.NumpyArrayIterator object at 0x000001E51B3484F0>
